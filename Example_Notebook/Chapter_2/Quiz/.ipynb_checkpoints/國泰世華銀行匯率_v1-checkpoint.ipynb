# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.cathaybk.com.tw/cathaybk/personal/deposit-exchange/rate/currency-billboard/'
resp=requests.get(url)
resp.encoding = 'utf-8'
soup=BeautifulSoup(resp.text,'lxml')
#soup

# %%
table = soup.find('table',class_="table-rate text-left")
table
# Out:
# <table class="table-rate text-left" width="100%">
# <colgroup>
# <col width="60%"/>
# </colgroup>
# <thead>
# <tr>
# <th width="46%">外幣幣別<br/>
# <span class="en">Currency</span></th>
# <th class="t_align_right" width="27%">銀行買進<br/>
# <span class="en">Bank buy</span></th>
# <th class="t_align_right" width="27%">銀行賣出<br/>
# <span class="en">Bank sell</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/USD.png)"></i>
# <font color="">美元(USD) US Dollars</font>
# </td>
# <td><font color="">30.7300</font></td>
# <td><font color="">30.9300</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/USD.png)"></i>
# <font color="#0000FF">美元現鈔(USD) US Dollar Cash</font>
# </td>
# <td><font color="#0000FF">30.4500</font></td>
# <td><font color="#0000FF">31.1500</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/CNY.png)"></i>
# <font color="">人民幣(CNY) Chinese Yuan</font>
# </td>
# <td><font color="">4.2560</font></td>
# <td><font color="">4.3560</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/CNY.png)"></i>
# <font color="#0000FF">人民幣現鈔(CNY) Chinese Yuan Cash</font>
# </td>
# <td><font color="#0000FF">4.1560</font></td>
# <td><font color="#0000FF">4.3760</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/HKD.png)"></i>
# <font color="">港幣(HKD) Hong Kong Dollars</font>
# </td>
# <td><font color="">3.8710</font></td>
# <td><font color="">3.9910</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/HKD.png)"></i>
# <font color="#0000FF">港幣現鈔(HKD) Hong Kong Dollar Cash</font>
# </td>
# <td><font color="#0000FF">3.7910</font></td>
# <td><font color="#0000FF">4.0310</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/GBP.png)"></i>
# <font color="">英鎊(GBP) Pound Sterling</font>
# </td>
# <td><font color="">37.2600</font></td>
# <td><font color="">38.0600</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/CHF.png)"></i>
# <font color="">瑞士法郎(CHF) Swiss Francs</font>
# </td>
# <td><font color="">30.8200</font></td>
# <td><font color="">31.3400</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/AUD.png)"></i>
# <font color="">澳大利亞幣(AUD) Australian Dollars</font>
# </td>
# <td><font color="">20.6000</font></td>
# <td><font color="">20.9800</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/SGD.png)"></i>
# <font color="">新加坡幣(SGD) Singapore Dollars</font>
# </td>
# <td><font color="">22.1200</font></td>
# <td><font color="">22.5200</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/CAD.png)"></i>
# <font color="">加拿大幣(CAD) Canadian Dollars</font>
# </td>
# <td><font color="">22.9500</font></td>
# <td><font color="">23.3500</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/SEK.png)"></i>
# <font color="">瑞典幣(SEK) Swedish Kronor</font>
# </td>
# <td><font color="">3.0160</font></td>
# <td><font color="">3.2060</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/ZAR.png)"></i>
# <font color="">南非幣(ZAR) South African Rand</font>
# </td>
# <td><font color="">1.9240</font></td>
# <td><font color="">2.1140</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/JPY.png)"></i>
# <font color="">日圓(JPY) Japanese Yen</font>
# </td>
# <td><font color="">0.2843</font></td>
# <td><font color="">0.2923</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/JPY.png)"></i>
# <font color="#0000FF">日圓現鈔(JPY) Japanese Yen Cash</font>
# </td>
# <td><font color="#0000FF">0.2803</font></td>
# <td><font color="#0000FF">0.2943</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/DKK.png)"></i>
# <font color="">丹麥幣(DKK) Danish Kroner</font>
# </td>
# <td><font color="">4.4500</font></td>
# <td><font color="">4.6100</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/THB.png)"></i>
# <font color="">泰國幣(THB) Thai Baht</font>
# </td>
# <td><font color="">0.9750</font></td>
# <td><font color="">1.0550</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/NZD.png)"></i>
# <font color="">紐西蘭幣(NZD) New Zealand Dollars</font>
# </td>
# <td><font color="">19.2800</font></td>
# <td><font color="">19.6800</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/EUR.png)"></i>
# <font color="">歐元(EUR) Euro</font>
# </td>
# <td><font color="">33.4200</font></td>
# <td><font color="">34.2200</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/EUR.png)"></i>
# <font color="#0000FF">歐元現鈔(EUR) Euro Cash</font>
# </td>
# <td><font color="#0000FF">32.9900</font></td>
# <td><font color="#0000FF">34.5700</font></td>
# </tr>
# <tr>
# <td>
# <i class="icon_currency" style="background-image: url(/CathayBK/Web/exchange/img/icon-currency/TRY.png)"></i>
# <font color="">土耳其里拉(TRY) Turkish Lira</font>
# </td>
# <td><font color="">4.9560</font></td>
# <td><font color="">5.6760</font></td>
# </tr>
# </tbody>
# </table>

# %%
ths=table.find('thead')
ths=[th.text.strip() for th in ths.find_all('th')]
ths=[th.replace('\n',' ') for th in ths]
ths
# Out:
# ['外幣幣別 Currency', '銀行買進 Bank buy', '銀行賣出 Bank sell']

# %%
trs=table.find('tbody').find_all('tr')
datas=[]

for tr in trs:
    tds=[td.text.strip() for td in tr.find_all('td')]
    datas.append(tds)

datas
# Out:
# [['美元(USD) US Dollars', '30.7300', '30.9300'],
#  ['美元現鈔(USD) US Dollar Cash', '30.4500', '31.1500'],
#  ['人民幣(CNY) Chinese Yuan', '4.2560', '4.3560'],
#  ['人民幣現鈔(CNY) Chinese Yuan Cash', '4.1560', '4.3760'],
#  ['港幣(HKD) Hong Kong Dollars', '3.8710', '3.9910'],
#  ['港幣現鈔(HKD) Hong Kong Dollar Cash', '3.7910', '4.0310'],
#  ['英鎊(GBP) Pound Sterling', '37.2600', '38.0600'],
#  ['瑞士法郎(CHF) Swiss Francs', '30.8200', '31.3400'],
#  ['澳大利亞幣(AUD) Australian Dollars', '20.6000', '20.9800'],
#  ['新加坡幣(SGD) Singapore Dollars', '22.1200', '22.5200'],
#  ['加拿大幣(CAD) Canadian Dollars', '22.9500', '23.3500'],
#  ['瑞典幣(SEK) Swedish Kronor', '3.0160', '3.2060'],
#  ['南非幣(ZAR) South African Rand', '1.9240', '2.1140'],
#  ['日圓(JPY) Japanese Yen', '0.2843', '0.2923'],
#  ['日圓現鈔(JPY) Japanese Yen Cash', '0.2803', '0.2943'],
#  ['丹麥幣(DKK) Danish Kroner', '4.4500', '4.6100'],
#  ['泰國幣(THB) Thai Baht', '0.9750', '1.0550'],
#  ['紐西蘭幣(NZD) New Zealand Dollars', '19.2800', '19.6800'],
#  ['歐元(EUR) Euro', '33.4200', '34.2200'],
#  ['歐元現鈔(EUR) Euro Cash', '32.9900', '34.5700'],
#  ['土耳其里拉(TRY) Turkish Lira', '4.9560', '5.6760']]

# %%
import csv

if datas!=[]:
    with open('國泰世華銀行匯率.csv','w',newline='',encoding='utf-8-sig') as f:
        writer=csv.writer(f)
        writer.writerow(ths)
        writer.writerows(datas)
    print('檔案輸出完畢')
# Out:
# 檔案輸出完畢
