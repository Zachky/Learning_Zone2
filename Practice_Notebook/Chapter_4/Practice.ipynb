# %%
from selenium import webdriver as WD
from selenium.webdriver.chrome.service import Service as Chrome_Sev
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import Zach_Library as Zach

# %%
strPath = 'C:\Web driver\Chrome\chromedriver.exe'

ServiceChrome = Chrome_Sev(strPath)
ServiceChrome

# %%
url = 'https://tw.yahoo.com/'
Test_Chrome = WD.Chrome(service=ServiceChrome)
Test_Chrome.get(url)

# %%
Soup = Zach.BeautifulSoup(Test_Chrome.page_source,'lxml')
Soup
# Out:
# <html class="artemis H(maxc) enableGAMAds" id="atomic" lang="zh-Hant-TW" style=""><head><title>Yahoo奇摩</title><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="on" http-equiv="x-dns-prefetch-control"/><meta content="chrome=1" http-equiv="X-UA-Compatible"/><meta content="Yahoo奇摩提供即時新聞、氣象、購物、信箱、搜尋、政治、國際、運動、股市、娛樂、科技、電影、汽機車、旅遊、遊戲。每天賺奇摩值、發掘更多精彩內容、一站獲取豐富生活！" name="description"/><meta content="Yahoo奇摩提供即時新聞、氣象、購物、信箱、搜尋、政治、國際、運動、股市、娛樂、科技、電影、汽機車、旅遊、遊戲。每天賺奇摩值、發掘更多精彩內容、一站獲取豐富生活！" property="og:description"/><meta content="yahoo, yahoo奇摩, yahoo奇摩首頁, yahoo首頁, yahoo搜尋, yahoo 信箱, yahoo 即時通訊, 新聞, 股市, 運動, 娛樂, 拍賣, 購物中心, 超級商城" name="keywords"/><meta content="399384933466174" property="fb:app_id"/><meta content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png" property="og:image"/><meta content="230899156962824" property="fb:pages"/><meta content="http://tw.yahoo.com" property="og:url"/><meta content="Yahoo奇摩" property="og:title"/><meta content="guce.yaho
# ...

# %% [markdown]
# > stock

# %%
xpath = '/html/body/div[1]/div/nav/div/div[1]/div/div/div[1]/ul[1]/li[2]/a'
Link_Stock = Test_Chrome.find_element(By.XPATH,xpath)
Link_Stock
# Link_Stock = Zach.find_elemental(Test_Chrome,xpath)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fcdbf10ad4917228b4fb1e4dccd9446a", element="6AD135EDB0581BF20F052E168216AB86_element_52")>

# %%
Link_Stock.click()

# %% [markdown]
# > Stock Query

# %%
xpath = '/html/body/div[1]/div/div/div/div/div[3]/div[1]/div/div[2]/div[1]/div[1]/div[1]/div[1]/input'
Query_Input = Test_Chrome.find_element(By.XPATH,xpath)
Query_Input
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fcdbf10ad4917228b4fb1e4dccd9446a", element="97C488BC8D397FCDECBF4F9F6869F9D0_element_56")>

# %%
import time

Query_Input.clear()
time.sleep(1)
Query_Input.send_keys('台積電')
time.sleep(1)
Query_Input.send_keys(Keys.ENTER)

# %% [markdown]
# > Practice : get information
